# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import FigSetup, AxionPhoton, MySaveFig, BlackHoleSpins, FilledLimit, line_background

# %%
plt.rcParams['axes.labelsize'] = 'xx-large'
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman"]
plt.rcParams["mathtext.fontset"] = "stix"
for tick in ['xtick', 'ytick']:
    plt.rcParams[f'{tick}.labelsize'] = 'x-large'
    plt.rcParams[f'{tick}.minor.pad'] = 3.9
    plt.rcParams[f'{tick}.minor.size'] = 2.5
    plt.rcParams[f'{tick}.minor.width'] = 1. # 0.6
    plt.rcParams[f'{tick}.major.pad'] = 4.0
    plt.rcParams[f'{tick}.major.size'] = 4.0
    plt.rcParams[f'{tick}.major.width'] = 1.2 # 0.8

# %%
fig,ax = FigSetup(
    Shape='Rectangular',
    ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',
    #xtick_rotation=0,
    mathpazo=False,
    m_min=1e-12,
    m_max=1e3,
    g_max=1e-9, g_min=1e-16)

AxionPhoton.QCDAxion(ax, KSVZ_on=False, DFSZ_on=False)

my_col = 'skyblue'
my_text_on = True

# alp DM decay
color="0.5"
AxionPhoton.DiffuseGammaRays(ax, text_on=text_on, col=color) 
AxionPhoton.SN1987A_decay(ax, text_on=text_on, col=color)
AxionPhoton.SN1987A_HeavyALP_nu(ax, text_on=text_on, col=color)
AxionPhoton.MUSE(ax, text_on=text_on, col=color)
AxionPhoton.JWST(ax, text_on=text_on, col=color)
AxionPhoton.VIMOS(ax, text_on=text_on, col=color)
AxionPhoton.GammaRayAttenuation(ax, text_on=text_on, col=color, zorder=-1)
AxionPhoton.HST(ax, text_on=text_on, col=color)
AxionPhoton.XMMNewton(ax, text_on=text_on, col=color)
AxionPhoton.INTEGRAL(ax, text_on=text_on, col=color)
AxionPhoton.NuSTAR(ax, text_on=text_on, col=color)
AxionPhoton.LeoT(ax, text_on=text_on, col=color)
AxionPhoton.Xrays(ax,text_on=text_on, col=color)
AxionPhoton.CMBAnisotropies(ax,text_on=text_on, col=color)
AxionPhoton.IonisationFraction(ax,text_on=text_on, col=color)
AxionPhoton.COBEFIRAS(ax,text_on=False, col=color)
AxionPhoton.GammaRayDecayCompilation(ax,text_on=text_on, col=color)
AxionPhoton.WINERED(ax,text_on=False, col=color)
AxionPhoton.CosmicBackground(ax,text_on=my_text_on, col=[my_col, my_col, my_col],
                             zorder=2, text_pos=[8e0, 6e-10])



# solar basin & stab
AxionPhoton.SolarBasin(ax, text_on=text_on, col=color)
AxionPhoton.StAB(ax, text_on=text_on, col=color)

# Haloscopes
col="0.7"
projection=False
fs=20
AxionPhoton.ADMX(ax, projection=projection, fs=fs, text_on=text_on, col=col)
AxionPhoton.HAYSTAC(ax, projection=projection, text_on=text_on, col=col) 
AxionPhoton.ABRACADABRA(ax, fs=fs, projection=False, text_on=text_on, col=col) 
AxionPhoton.SHAFT(ax, text_on=text_on, col=col) 
AxionPhoton.ORGAN(ax, projection=projection, text_on=text_on, lw=0, col=col) 
AxionPhoton.UPLOAD(ax, text_on=text_on, col=col) 
AxionPhoton.TASEH(ax, text_on=False, col=col) 
AxionPhoton.CASTCAPP(ax, text_on=False, col=col) 
AxionPhoton.RBF_UF(ax, fs=fs - 2, text_on=text_on, col=col)
AxionPhoton.CAPP(ax, fs=fs - 4, text_on=text_on, col=col)
AxionPhoton.QUAX(ax, text_on=text_on, col=col)
AxionPhoton.BASE(ax, text_on=text_on, arrow_on=False, col=col)
AxionPhoton.ADMX_SLIC(ax, fs=fs - 8, text_on=text_on, col=col)


# stellar bounds
color="0.9"
text_on = False
AxionPhoton.GlobularClusters(ax, text_on=text_on, col=color)
AxionPhoton.SolarNu(ax, text_on=text_on, col=color)
AxionPhoton.WhiteDwarfs(ax, text_on=text_on, col=color)
AxionPhoton.NeutronStars(ax, col=color, text_on=text_on)
#AxionPhoton.AxionStarExplosions(ax, col=color, text_on=text_on)

# helioscope
AxionPhoton.Helioscopes(ax, col='0.5')

# astro bounds
edgealpha=0.5
lw=0.5
col="0.6"
AxionPhoton.FermiSNe(ax, text_on=my_text_on, edgealpha=edgealpha, lw=lw, col=my_col, zorder=1.5)
AxionPhoton.DSNALP(ax, text_on=text_on, edgealpha=edgealpha, lw=lw, col=col)
AxionPhoton.Hydra(ax, text_on=text_on, edgealpha=edgealpha, lw=lw, col=col)
AxionPhoton.M87(ax, text_on=text_on, edgealpha=edgealpha, lw=lw, col=col)
AxionPhoton.Mrk421(ax, text_on=text_on, edgealpha=edgealpha, lw=lw, col=col)
AxionPhoton.Fermi(ax, text_on=my_text_on, edgealpha=edgealpha, lw=lw, col=my_col)
AxionPhoton.StarClusters(ax, text_on=text_on, edgealpha=edgealpha,
                        lw=lw, col=col)
AxionPhoton.FermiQuasars(ax, text_on=my_text_on, edgealpha=edgealpha,
                         lw=lw, col=my_col)
AxionPhoton.NGC1275(ax, text_on=text_on, edgealpha=edgealpha,
                    lw=lw, col=col)
AxionPhoton.H1821643(ax, text_on=False, edgealpha=edgealpha, lw=lw, col=col)
AxionPhoton.SN1987A_gamma(ax, text_on=False, edgealpha=edgealpha,
                          lw=lw, col=col)
AxionPhoton.HESS(ax, edgealpha=edgealpha, lw=lw, text_on=False, col=my_col)
AxionPhoton.HAWC(ax, edgealpha=edgealpha, lw=lw, text_on=False, col=col)
AxionPhoton.MWDXrays(ax, text_on=text_on, edgealpha=edgealpha,
                                  lw=lw, col=col)
AxionPhoton.MWDPolarisation(ax, text_on=text_on,
                            edgealpha=edgealpha, lw=lw, col=col)
AxionPhoton.PulsarPolarCap(ax, text_on=text_on,
                           edgealpha=edgealpha, lw=lw, col=col)

# LSW
AxionPhoton.ALPS(ax, projection=True, text_on=my_text_on, col=color, 
                 col_proj='red', lw_proj=5, zorder_proj=20, text_shift_y=0.02,
                 text_shift_x=1.5e-1)  # extend this
AxionPhoton.PVLAS(ax, text_on=text_on, col=color)
AxionPhoton.OSQAR(ax, text_on=text_on, col=color)
AxionPhoton.CROWS(ax, text_on=text_on, col=color)


# DM scenarios
# ALP mass doesn't exceed 3H at matter-radiation equality: https://arxiv.org/pdf/1201.5902.pdf
dat = loadtxt("limit_data/AxionPhoton/ALP_CDM.txt")
plt.plot(dat[:,0],dat[:,1],'--',lw=2,zorder=0.091,alpha=1,color='#5232a8')

# Post-inflation ALPs from strings
def ALP_n0(m,gstar_T1=90,C_agamma=1):
    g = C_agamma/(137*2*pi)*sqrt(2*5.45)/1.9e13*(m/1e-6)**(1/4)*(90/gstar_T1)**(1/8)
    return g
m = array([1e-12,1e2])
ax.fill_between(m,ALP_n0(m,60,0.1),ALP_n0(m,100,10.0),color='#82a1ad',alpha=0.7,lw=0,zorder=-10)
# ax.plot(m,ALP_n0(m,100,10.0),color='k',lw=1.5,zorder=-10,alpha=0.9)

# ALP Cogenesis: https://arxiv.org/pdf/2006.04809.pdf
def ALP_Cogenesis(m,C_agamma=1,T_EW=130,cb=0.1):
    g = C_agamma*1.8e-11*(0.1/cb)**0.5*(m/1e-3)**0.5*(130/T_EW)
    return g
ax.fill_between(m,ALP_Cogenesis(m,1),ALP_Cogenesis(m,10.0),color='#90d0de',alpha=0.7,lw=3,zorder=-1)
# ax.plot(m,ALP_Cogenesis(m,1),'k-',lw=1.5,zorder=-1,alpha=0.9)
# ax.plot(m,ALP_Cogenesis(m,10),'k-',lw=1.5,zorder=-1,alpha=0.9)




# Early matter domination ALPs https://arxiv.org/pdf/1905.06952.pdf
EMD_lower = 1.448226539542627e-19
EMD_upper = 2.6761051177154226e-18
ax.fill_between(m,[EMD_upper*10,EMD_upper*10],[EMD_lower/10,EMD_lower/10],
                color='#088a8a',alpha=0.2,lw=0,zorder=-100)

# ZN Trapped misalignment
mZN = array([1.0653299674040958e-12,2.918208237644098e-11,2.918208237644098e-11,1.5573599658335155e-8,0.0022436307015499075])
g_l = array([1.0286554671761714e-20,1.0213697671946902e-20,8.743762161885345e-19,4.600829019121313e-16,6.708200767131382e-11])
g_u = array([3.881119860187495e-18,3.31069516677389e-17,3.310695166773917e-17,2.0277194781728075e-15,2.9212601936408154e-10])
ax.fill_between(mZN,g_u,g_l,color='#518891',alpha=0.9,lw=0,zorder=-5)
# ax.plot(mZN,g_u,'k-',lw=1.5,zorder=-5,alpha=0.9)
# ax.plot(mZN,g_l,'k-',lw=1.5,zorder=-5,alpha=0.9)

m = array([1e-12,30e-3])
plt.fill_between(m,2e-10*0.1*m,y2=2e-10*10*m,alpha=0.9,color='gold',zorder=-0.1)
# plt.plot(m,2e-10*0.1*m,'-',color='k',zorder=0,alpha=1,lw=1.5)
# plt.plot(m,2e-10*10*m,'-',color='k',zorder=0,alpha=1,lw=1.5)

m = array([30e-3,1e3])
plt.fill_between(m,2e-10*0.1*m,y2=2e-10*10*m,alpha=0.3,color='gold',zorder=-0.1,hatch='+',edgecolor='k')

plt.text(0.2e0,6e-15,r'${\bf Post-inflation}$',color='k',rotation=11,fontsize=25,ha='center',rotation_mode='anchor',alpha=0.5)
plt.text(0.2e0,6e-15/4,r'${\bf ALP misalignment}$',color='k',rotation=11,fontsize=25,ha='center',rotation_mode='anchor',alpha=0.5)

plt.text(0.7e-10,1.2e-14,r'${\bf ALP cogenesis}$',color='k',rotation=21,fontsize=27,alpha=0.5)

plt.text(0.12e-11,2e-18,r'${\bf Trapped~misalignment}$',color='k',fontsize=24,rotation=27,alpha=0.5)
plt.text(0.18e-11,0.7e-18,r'($\mathcal{Z}_\mathcal{N}$ axion)',color='k',fontsize=22,rotation=27,alpha=0.5)

plt.text(30e-3,2.5e-18,r'${\bf ALP misalignment}$',fontsize=25,color='k',ha='center',alpha=0.5)
plt.text(30e-3,2.5e-18/4,r'(early matter domination)',fontsize=25,color='k',ha='center',alpha=0.5)


plt.text(1.95e-10,1.34e-19,r'${\bf QCD axion}$',fontsize=25,color='k',alpha=0.5,rotation=38.5)
# plt.text(2.5e-9,1.25e-19,r'Pre-inflation, $\theta_i \in [0,\pi]$',fontsize=20,color='k',alpha=0.6,rotation=38.5)
# plt.text(1.2e-6,0.6e-16,r'Post-inflation ($N=1$)',fontsize=20,color='k',alpha=0.6,rotation=38.5)
# plt.text(1.2e-4,0.6e-14,r'Post-inflation ($N>1$)',fontsize=20,color='k',alpha=0.6,rotation=38.5)

plt.arrow(0.202, 0.527, 0.00, -0.02, head_width=0.008, head_length=0.01, linewidth=2, color='#5232a8', length_includes_head=False,transform=fig.transFigure,figure=fig)
plt.arrow(0.359, 0.620, 0.00, -0.02, head_width=0.008, head_length=0.01, linewidth=2, color='#5232a8', length_includes_head=False,transform=fig.transFigure,figure=fig)
plt.text(3e-11,0.6e-13,r'$m_a(T_{\rm eq}) > 3H(T_{\rm eq})$',fontsize=20,rotation=21.5,color='#5232a8')

m1 = 2.5e-9
m2 = 0.8e-6
plt.annotate('', (m1, 2e-10*m1*0.2), (m2, 2e-10*m2*0.2), arrowprops={'arrowstyle':'<-','lw':1.5,'alpha':1,'color':'#cf6700'},zorder=100)
plt.text(2.5e-9,2.25e-19,r'Anthropic, $\theta_i<0.1$',fontsize=20,color='#cf6700',alpha=1,rotation=38.5)

m1 = 0.8e-6
m2 = 7e-4
plt.annotate('', (m1, 2e-10*m1*0.2), (m2, 2e-10*m2*0.2), arrowprops={'arrowstyle':'<->','lw':1.5,'alpha':1,'color':'#cf6700'},zorder=100)
plt.text(1.5e-6,1.2e-16,r'$\theta_i \sim 1$',fontsize=20,color='#cf6700',alpha=1,rotation=38.5)

plt.text(0.26e-7,0.95e-17,r'${\bf Pre-inflation}$',fontsize=23,rotation=38.5,color='#cf6700')

m1 = 2e-5
m2 = 2e-4
plt.annotate('', (m1, 2e-10*m1*0.4), (m2, 2e-10*m2*0.4), arrowprops={'arrowstyle':'<->','lw':1.5,'alpha':1,'color':'#827804'},zorder=100)
plt.text(2e-5,0.35e-14,r'$N=1$',fontsize=20,color='#827804',alpha=1,rotation=38.5)

m1 = 7e-4
m2 = 30e-3
plt.annotate('', (m1, 2e-10*m1*0.4), (m2, 2e-10*m2*0.4), arrowprops={'arrowstyle':'<->','lw':1.5,'alpha':1,'color':'#827804'},zorder=100)
plt.text(2e-3,0.35e-12,r'$N>1$',fontsize=20,color='#827804',alpha=1,rotation=38.5)


plt.text(0.5e-4,0.25e-13,r'${\bf Post-inflation}$',fontsize=23,rotation=38.5,color='#827804')


# ADD: interferometer, SNe projection, gamma decay
# Out:
# Text(5e-05, 2.5e-14, '${\\bf Post-inflation}$')
