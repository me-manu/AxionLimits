# %%
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs import *

fig,ax = FigSetup(ylab='$|g_{a\gamma}|$ [GeV$^{-1}$]',xtick_rotation=0,mathpazo=False,m_min=1e-12,m_max=1e1,g_max=1e-8)
AxionPhoton.Helioscopes(ax,text_on=False,col='darkred')
AxionPhoton.HaloscopesUniform(ax,text_on=False,col='crimson')
AxionPhoton.GlobularClusters(ax,text_on=False,col=[0.0, 0.66, 0.42])
AxionPhoton.Mrk421(ax,text_on=False,col='SeaGreen',lw=0.5)
AxionPhoton.NGC1275(ax,text_on=False,col='SeaGreen',lw=0.5)
AxionPhoton.HESS(ax,text_on=False,col='SeaGreen',lw=0.5)
AxionPhoton.StarClusters(ax,text_on=False,col='SeaGreen',lw=0.5)
AxionPhoton.SN1987A_gamma(ax,text_on=False,col='SeaGreen',lw=0.5)
AxionPhoton.PulsarPolarCap(ax,col='seagreen',text_on=False,lw=0.5)
AxionPhoton.NuSTAR_Sun(ax,col='seagreen',text_on=False,lw=0.5)
AxionPhoton.MAGIC(ax,col='seagreen',text_on=False,lw=0.5)
AxionPhoton.M82(ax,col='seagreen',text_on=False,lw=0.5)
AxionPhoton.Fermi(ax,text_on=False,col='SeaGreen',lw=0.5)
AxionPhoton.FermiQuasars(ax,text_on=False,col='SeaGreen',lw=0.5)
AxionPhoton.MWDPolarisation(ax,col='seagreen',text_on=False,lw=0.5)
AxionPhoton.MWDXrays(ax,col='seagreen',text_on=False,lw=0.5)
AxionPhoton.MUSE(ax,col='seagreen',text_on=False)
AxionPhoton.JWST(ax,col='seagreen',text_on=False)
AxionPhoton.WINERED(ax,col='seagreen',text_on=False)
AxionPhoton.VIMOS(ax,col='seagreen',text_on=False)
AxionPhoton.HST(ax,col='seagreen',text_on=False,lw=0)
AxionPhoton.NeutronStars(ax,col='seagreen',text_on=False,lw=0.5)



# ALP mass doesn't exceed 3H at matter-radiation equality: https://arxiv.org/pdf/1201.5902.pdf
dat = loadtxt("limit_data/AxionPhoton/ALP_CDM.txt")
plt.plot(dat[:,0],dat[:,1],'--',lw=2,zorder=0.091,alpha=1,color='#5232a8')

# Formula for ALP CDM line:
# ma = logspace(-12,-9,10)
# fa = 5.2e10*(1e-12/ma)**0.5
# g = 1/(2*pi*137*fa)


# Post-inflation ALPs from strings
def ALP_n0(m,gstar_T1=90,C_agamma=1):
    g = C_agamma/(137*2*pi)*sqrt(2*5.45)/1.9e13*(m/1e-6)**(1/4)*(90/gstar_T1)**(1/8)
    return g
m = array([1e-12,1e2])
ax.fill_between(m,ALP_n0(m,60,0.1),ALP_n0(m,100,10.0),color='#82a1ad',alpha=0.7,lw=0,zorder=-10)
# ax.plot(m,ALP_n0(m,100,10.0),color='k',lw=1.5,zorder=-10,alpha=0.9)




# ALP Cogenesis: https://arxiv.org/pdf/2006.04809.pdf
def ALP_Cogenesis(m,C_agamma=1,T_EW=130,cb=0.1):
    g = C_agamma*1.8e-11*(0.1/cb)**0.5*(m/1e-3)**0.5*(130/T_EW)
    return g
ax.fill_between(m,ALP_Cogenesis(m,1),ALP_Cogenesis(m,10.0),color='#90d0de',alpha=0.7,lw=3,zorder=-1)
# ax.plot(m,ALP_Cogenesis(m,1),'k-',lw=1.5,zorder=-1,alpha=0.9)
# ax.plot(m,ALP_Cogenesis(m,10),'k-',lw=1.5,zorder=-1,alpha=0.9)




# Early matter domination ALPs https://arxiv.org/pdf/1905.06952.pdf
EMD_lower = 1.448226539542627e-19
EMD_upper = 2.6761051177154226e-18
ax.fill_between(m,[EMD_upper*10,EMD_upper*10],[EMD_lower/10,EMD_lower/10],
                color='#088a8a',alpha=0.2,lw=0,zorder=-100)
#plt.plot(m,[EMD_upper*10,EMD_upper*10],color='k',zorder=-100,lw=1.5,alpha=0.9)




# ZN Trapped misalignment
mZN = array([1.0653299674040958e-12,2.918208237644098e-11,2.918208237644098e-11,1.5573599658335155e-8,0.0022436307015499075])
g_l = array([1.0286554671761714e-20,1.0213697671946902e-20,8.743762161885345e-19,4.600829019121313e-16,6.708200767131382e-11])
g_u = array([3.881119860187495e-18,3.31069516677389e-17,3.310695166773917e-17,2.0277194781728075e-15,2.9212601936408154e-10])
ax.fill_between(mZN,g_u,g_l,color='#518891',alpha=0.9,lw=0,zorder=-5)
# ax.plot(mZN,g_u,'k-',lw=1.5,zorder=-5,alpha=0.9)
# ax.plot(mZN,g_l,'k-',lw=1.5,zorder=-5,alpha=0.9)






m = array([1e-12,30e-3])
plt.fill_between(m,2e-10*0.1*m,y2=2e-10*10*m,alpha=0.9,color='gold',zorder=-0.1)
# plt.plot(m,2e-10*0.1*m,'-',color='k',zorder=0,alpha=1,lw=1.5)
# plt.plot(m,2e-10*10*m,'-',color='k',zorder=0,alpha=1,lw=1.5)

m = array([30e-3,1e3])
plt.fill_between(m,2e-10*0.1*m,y2=2e-10*10*m,alpha=0.3,color='gold',zorder=-0.1,hatch='+',edgecolor='k')
# plt.plot(m,2e-10*0.1*m,'-',color='k',zorder=0,alpha=0.4,lw=1.5)
# plt.plot(m,2e-10*10*m,'-',color='k',zorder=0,alpha=0.4,lw=1.5)

# m = array([1e-6,1e-4,1e-4,1e-6,1e-6])
# g = 2e-10*m*array([0.1,0.1,10,10,0.1])
# plt.plot(m,g,'-',color='k',zorder=0,alpha=1,lw=1.5)

# m = array([1e-11,1e-6,1e-6,1e-11,1e-11])
# g = 2e-10*m*array([0.1,0.1,10,10,0.1])
# plt.plot(m,g,'-',color='k',zorder=0,alpha=1,lw=1.5)

# m = array([1e-4,1e-1,1e-1,1e-4,1e-4])
# g = 2e-10*m*array([0.1,0.1,10,10,0.1])
# plt.plot(m,g,'-',color='k',zorder=0,alpha=1,lw=1.5)



plt.text(1.3e0,0.2e-12,r'${\bf Telescopes}$',fontsize=20,color='seagreen',rotation=90)
plt.text(0.3e-11,0.8e-11,r'${\bf Astrophysics}$',fontsize=23,color='w',rotation=0,path_effects=line_background(1.5,'k'))
plt.text(2.4e-11,2e-10,r'${\bf SHAFT}$',rotation=0,color='w',fontsize=20,alpha=1)
plt.text(0.7e-9,4e-10,r'${\bf ABRA}$',rotation=0,color='w',fontsize=20,alpha=1)
plt.text(4.1e-6,2e-13,r'${\bf Haloscopes}$',rotation=90,color='w',fontsize=20)
plt.text(0.8e0,0.7e-10,r'${\bf Stars}$',fontsize=30,color='w',path_effects=line_background(1.5,'k'))
plt.text(1e-3,0.9e-10,r'${\bf CAST}$',fontsize=30,color='w',path_effects=line_background(1.5,'k'))

plt.text(0.2e0,6e-15,r'${\bf Post-inflation}$',color='k',rotation=11,fontsize=25,ha='center',rotation_mode='anchor',alpha=0.5)
plt.text(0.2e0,6e-15/4,r'${\bf ALP misalignment}$',color='k',rotation=11,fontsize=25,ha='center',rotation_mode='anchor',alpha=0.5)

plt.text(0.7e-10,1.2e-14,r'${\bf ALP cogenesis}$',color='k',rotation=21,fontsize=27,alpha=0.5)

plt.text(0.12e-11,2e-18,r'${\bf Trapped~misalignment}$',color='k',fontsize=24,rotation=27,alpha=0.5)
plt.text(0.18e-11,0.7e-18,r'($\mathcal{Z}_\mathcal{N}$ axion)',color='k',fontsize=22,rotation=27,alpha=0.5)

plt.text(30e-3,2.5e-18,r'${\bf ALP misalignment}$',fontsize=25,color='k',ha='center',alpha=0.5)
plt.text(30e-3,2.5e-18/4,r'(early matter domination)',fontsize=25,color='k',ha='center',alpha=0.5)


plt.text(1.95e-10,1.34e-19,r'${\bf QCD axion}$',fontsize=25,color='k',alpha=0.5,rotation=38.5)
# plt.text(2.5e-9,1.25e-19,r'Pre-inflation, $\theta_i \in [0,\pi]$',fontsize=20,color='k',alpha=0.6,rotation=38.5)
# plt.text(1.2e-6,0.6e-16,r'Post-inflation ($N=1$)',fontsize=20,color='k',alpha=0.6,rotation=38.5)
# plt.text(1.2e-4,0.6e-14,r'Post-inflation ($N>1$)',fontsize=20,color='k',alpha=0.6,rotation=38.5)

plt.arrow(0.202, 0.527, 0.00, -0.02, head_width=0.008, head_length=0.01, linewidth=2, color='#5232a8', length_includes_head=False,transform=fig.transFigure,figure=fig)
plt.arrow(0.359, 0.620, 0.00, -0.02, head_width=0.008, head_length=0.01, linewidth=2, color='#5232a8', length_includes_head=False,transform=fig.transFigure,figure=fig)
plt.text(3e-11,0.6e-13,r'$m_a(T_{\rm eq}) > 3H(T_{\rm eq})$',fontsize=20,rotation=21.5,color='#5232a8')

plt.gcf().text(0.82, 0.83, r'$C_{a\gamma}\in [0.1,10]$',ha='center',color='black',multialignment='center',
               bbox=dict(facecolor='w', linewidth=1.5,
                         edgecolor='black', boxstyle='round,pad=0.2'));

m1 = 2.5e-9
m2 = 0.8e-6
plt.annotate('', (m1, 2e-10*m1*0.2), (m2, 2e-10*m2*0.2), arrowprops={'arrowstyle':'<-','lw':1.5,'alpha':1,'color':'#cf6700'},zorder=100)
plt.text(2.5e-9,2.25e-19,r'Anthropic, $\theta_i<0.1$',fontsize=20,color='#cf6700',alpha=1,rotation=38.5)

m1 = 0.8e-6
m2 = 7e-4
plt.annotate('', (m1, 2e-10*m1*0.2), (m2, 2e-10*m2*0.2), arrowprops={'arrowstyle':'<->','lw':1.5,'alpha':1,'color':'#cf6700'},zorder=100)
plt.text(1.5e-6,1.2e-16,r'$\theta_i \sim 1$',fontsize=20,color='#cf6700',alpha=1,rotation=38.5)

plt.text(0.26e-7,0.95e-17,r'${\bf Pre-inflation}$',fontsize=23,rotation=38.5,color='#cf6700')

m1 = 2e-5
m2 = 2e-4
plt.annotate('', (m1, 2e-10*m1*0.4), (m2, 2e-10*m2*0.4), arrowprops={'arrowstyle':'<->','lw':1.5,'alpha':1,'color':'#827804'},zorder=100)
plt.text(2e-5,0.35e-14,r'$N=1$',fontsize=20,color='#827804',alpha=1,rotation=38.5)

m1 = 7e-4
m2 = 30e-3
plt.annotate('', (m1, 2e-10*m1*0.4), (m2, 2e-10*m2*0.4), arrowprops={'arrowstyle':'<->','lw':1.5,'alpha':1,'color':'#827804'},zorder=100)
plt.text(2e-3,0.35e-12,r'$N>1$',fontsize=20,color='#827804',alpha=1,rotation=38.5)


plt.text(0.5e-4,0.25e-13,r'${\bf Post-inflation}$',fontsize=23,rotation=38.5,color='#827804')

MySaveFig(fig,'AxionPhoton_ALPDM')

# %%
from PlotFuncs import Axion_fa
        
fig,ax = FigSetup(Shape='Square',ylab=r'$1/f_a$ [GeV$^{-1}$]',mathpazo=True,\
                              g_min=1e-17,g_max=1e-8,m_min=5e-12,m_max=1e-4,xtick_rotation=0)

def ALP_n0(m,gstar_T1=90):
    fa_inv = sqrt(2*5.45)/1.9e13*(m/1e-6)**(1/4)*(90/gstar_T1)**(1/8)
    return fa_inv
m = array([1e-12,1e2])
ax.fill_between(m,ALP_n0(m,60),ALP_n0(m,100),color='#08458a',alpha=1,lw=3,zorder=0)


BlackHoleSpins(ax,1,[0.6e-13,0.4e-17],text_on=False,alpha=1,facecolor='gray')
Axion_fa.QCDAxion(ax,QCD_label_mass=3e-6,shading_on=False,text_col='goldenrod',text_on=False)
Axion_fa.SolarCore(ax,text_pos=[0.3e-10,0.25e-10],text_rot=39,col='seagreen')
Axion_fa.SN1987A(ax,text_pos=[4e-5,0.35e-8])



dat = loadtxt('limit_data/AxionPhoton/Projections/DMRadio.txt')
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1e0,zorder=-100,lw=3,color='crimson',alpha=0.1)
plt.plot(dat[:,0],dat[:,1]*(137*2*pi),'--',zorder=-100,lw=3,color='crimson')
plt.text(4e-8,2e-15,r'{\bf DM-Radio}',color='crimson',rotation=42,fontsize=22)
plt.text(0.8e-7,1.8e-15,r'$C_{a\gamma}=1$',color='crimson',rotation=43,fontsize=22)

dat = loadtxt('limit_data/AxionNeutron/Projections/CASPEr_wind.txt')
dat[:,1] *= 2*AxionNeutron.m_n
plt.fill_between(dat[:,0],dat[:,1]/AxionNeutron.m_n,y2=1e0,zorder=-100,lw=3,color='crimson',alpha=0.1)
plt.plot(dat[:,0],dat[:,1]/AxionNeutron.m_n,'--',zorder=-100,lw=3,color='crimson')
plt.text(2e-9,8e-13,r'{\bf CASPEr-gradient}',color='crimson',rotation=25,fontsize=22)
plt.text(0.7e-8,8e-13,r'$C_{an}=1$',color='crimson',rotation=25,fontsize=22)


# https://arxiv.org/abs/hep-ph/9908508
Axion_fa.CASPEr(ax,text_pos=[1.5e-9,8e-16],text_rot=59)
plt.text(2.6e-9,7e-16,r'$C_{\rm EDM} = 2.4\times 10^{-16}$ cm',color='crimson',rotation=59,fontsize=18)


plt.text(7e-12,0.3e-16,r'{\bf Black hole spins}',fontsize=25,color='k',rotation=90)

plt.text(0.25e-5,1e-12,r'{\bf QCD axion}',color='goldenrod',fontsize=30,rotation=39,path_effects=line_background(1.5,'k'))


plt.text(1e-5,1e-13,r'{\bf Post-inflation}',color='#08458a',rotation=12,fontsize=24,ha='center')
plt.text(1e-5,0.55e-13,r'{\bf misalignment}',color='#08458a',rotation=12,fontsize=24,ha='center')
plt.text(1e-5,0.3e-13,r'(inc. strings)',color='#08458a',rotation=11,fontsize=24,ha='center')

MySaveFig(fig,'fa_ALPDM_n0_only')

# %%
import cmasher as cmr

fig,ax = FigSetup(Shape='Square',ylab=r'$1/f_a$ [GeV$^{-1}$]',mathpazo=True,\
                              g_min=1e-14,g_max=1e-11,m_min=1e-12,m_max=1e-3,xtick_rotation=0)

BlackHoleSpins(ax,1,[0.6e-13,0.4e-17],text_on=False,alpha=1,facecolor='gray')
Axion_fa.QCDAxion(ax,QCD_label_mass=3e-6,shading_on=False,text_col='k',text_on=False)
Axion_fa.SN1987A(ax,text_pos=[4e-5,0.35e-8])

def fa_TD_ALP(m,n,theta_eff):
    m_pl = 2.4e18
    gstar = 75
    cn = (2/5)*(1+n/5)
    npow = (n/(2*(n+4)))
    sqrt_m0m1 = (m_pl/(cn*1.66*sqrt(gstar)))**npow
    fa = (1e12**2*1.265/(9e-3*theta_eff**2*sqrt(m/1e-6)*sqrt_m0m1))**(1/(2-npow))
    return fa

def fa_TD_ALP_alt(m,n,theta_eff,tau_star=16):
    m_pl = 2.4e18
    gstar = 75
    sqrt_m0m1 = tau_star**(n/4)
    fa = (1e12**2*1.265/(9e-3*theta_eff**2*sqrt(m/1e-6)*sqrt_m0m1))**(1/2)
    return fa

th_eff = [2.33,2.02,1.81,1.69,1.59,1.56,1.48]

cols = cmr.pride(linspace(0.15,0.85,7))

m = array([1e-12,1e2])

zo = -100
for i in range(0,7):
    plt.plot(m,fa_TD_ALP(m,i,th_eff[i])**-1,'-',lw=3,path_effects=line_background(5,'k'),color=cols[i,:],zorder=-50)
    plt.fill_between(m,fa_TD_ALP(m,i,th_eff[i])**-1,y2=fa_TD_ALP(m,6,th_eff[6])**-1,color=cols[i,:],zorder=zo)
    zo += 1


    
    

dat = loadtxt('limit_data/AxionPhoton/Projections/DMRadio.txt')
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1e0,zorder=0,lw=3,color='crimson',alpha=0.1)
plt.plot(dat[:,0],dat[:,1]*(137*2*pi),':',zorder=0,lw=3,color='crimson')
plt.text(3e-7,2e-14,r'{\bf DM-Radio}',color='crimson',rotation=72,fontsize=22)
plt.text(6e-7,2.1e-14,r'$C_{a\gamma}=1$',color='crimson',rotation=72,fontsize=22)

dat = loadtxt('limit_data/AxionNeutron/Projections/CASPEr_wind.txt')
dat[:,1] *= 2*AxionNeutron.m_n
plt.fill_between(dat[:,0],dat[:,1]/AxionNeutron.m_n,y2=1e0,zorder=-10,lw=3,color='darkred',alpha=0.1)
plt.plot(dat[:,0],dat[:,1]/AxionNeutron.m_n,'--',zorder=-10,lw=3,color='darkred')
plt.text(2.5e-9,8e-13,r'{\bf CASPEr-gradient}',color='darkred',rotation=59,fontsize=22)
plt.text(0.9e-8,1e-12,r'$C_{an}=1$',color='darkred',rotation=59,fontsize=22)


# https://arxiv.org/abs/hep-ph/9908508
Axion_fa.CASPEr(ax,text_pos=[0.4e-8,1.2e-14],text_rot=80,col='#a83279')
plt.text(0.8e-8,1.2e-14,r'$C_{\rm EDM} = 2.4\times 10^{-16}$ cm',color='#a83279',rotation=80,fontsize=18)
    
    
plt.text(6e-5,3.3e-12,r'$n = 6$',color=cols[6,:],rotation=40,fontsize=35)
plt.text(9e-5,0.48e-12,r'$n = 0$',color=cols[0,:],rotation=36,fontsize=35)
plt.text(4e-6,2e-12,r'{\bf QCD axion}',color='gold',fontsize=35,rotation=70,path_effects=line_background(1.5,'k'))
plt.text(2e-12,0.3e-13,r'{\bf Black hole spins}',fontsize=35,color='k',rotation=90)


plt.gcf().text(0.88,0.15,r'$\frac{m_a}{m_a(T_1)} = \frac{T_1}{\sqrt{m_a f_a}}$',ha='right',fontsize=30)


MySaveFig(fig,'fa_ALPDM')

# %%
import cmasher as cmr
from PlotFuncs import UpperFrequencyAxis_Simple



fig,ax = FigSetup(ylab=r'$1/f_a$ [GeV$^{-1}$]',mathpazo=True,\
                              g_min=1e-19,g_max=1e-5,m_min=1e-15,m_max=1e3,xtick_rotation=20,tfs=25)


dat = loadtxt('limit_data/AxionPhoton/Combined_DarkMatterAstro.txt')
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1e0,zorder=0,lw=1.5,color='gray',edgecolor='k')
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1,zorder=0,lw=0.5,edgecolor='dimgray',facecolor='none',hatch='x',alpha=0.1)

dat = loadtxt('limit_data/AxionPhoton/Haloscopes_Combined_microeV-meV.txt')
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1e0,zorder=0,lw=1.5,color='gray',edgecolor='k')
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1,zorder=0,lw=0.5,edgecolor='dimgray',facecolor='none',hatch='x',alpha=0.1)
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1e0,zorder=0,lw=1.5,color='none',edgecolor='k')

dat = loadtxt('limit_data/AxionPhoton/Combined_Astro.txt')
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1e0,zorder=0,lw=1.5,color='gray',edgecolor='k')
plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1,zorder=0,lw=0.5,color='dimgray',edgecolor='dimgray',facecolor='none',hatch='X',alpha=0.1)

dat = loadtxt('limit_data/fa/BlackHoleSpins_Hoof.txt')
plt.fill_between(dat[:,0],dat[:,1],y2=1e-99,zorder=-1,lw=1.5,color='gray',edgecolor='k')
plt.fill_between(dat[:,0],dat[:,1],y2=1e-99,zorder=-1,lw=0.5,color='dimgray',edgecolor='dimgray',facecolor='none',hatch='/',alpha=0.1)

plt.fill_between(array([1e-31,1e5]),[1.3e-9/0.935,1.3e-9/0.935],y2=1,zorder=-1,lw=1.5,color='lightgray',edgecolor='k')
plt.fill_between(array([1e-31,1e5]),[1.3e-9/0.935,1.3e-9/0.935],y2=1,zorder=-1,lw=0.5,color='gray',edgecolor='gray',facecolor='none',hatch='\\',alpha=0.1)


#dat = loadtxt('limit_data/AxionPhoton/Projections/HaloscopeProjections_Combined.txt')
#plt.fill_between(dat[:,0],dat[:,1]*(137*2*pi),y2=1e0,zorder=0,lw=0,color='#6e9971',alpha=0.1)
#plt.plot(dat[:,0],dat[:,1]*(137*2*pi),'--',zorder=0,lw=1,color='#6e9971')
# # plt.text(3e-7,2e-14,r'{\bf Haloscopes}',color='crimson',rotation=72,fontsize=22)
# # plt.text(6e-7,2.1e-14,r'$C_{a\gamma}=1$',color='crimson',rotation=72,fontsize=22)




m = array([1e-31,1e5])

# Post-inflation ALP
def ALP_n0(m,theta_i=2.33,gstar_T1=90):
    fa_inv = sqrt(2*theta_i**2)/1.9e13*(m/1e-6)**(1/4)*(90/gstar_T1)**(1/8)
    return fa_inv
ax.fill_between(m,ALP_n0(m,theta_i=0.1),ALP_n0(m,theta_i=pi-0.1),color='#6e9971',alpha=1,lw=0,zorder=-10)
ax.plot(m,ALP_n0(m,theta_i=0.1),'k-',lw=1.5,zorder=-10)
ax.plot(m,ALP_n0(m,theta_i=pi-0.1),'k-',lw=1.5,zorder=-10)
ax.text(1e-3,1.5e-13,r'{\bf ALP misalignment}',color='k',fontsize=20,rotation=12)
ax.plot(m,ALP_n0(m,gstar_T1=100),'--',color='k',zorder=-10,alpha=0.8)
ax.text(0.1e-4,1.5e-13,r'Post-inflation',color='k',fontsize=15,rotation=12,alpha=0.8)



# Trapped misalignment
dat = loadtxt("limit_data/fa/TrappedMisalignment.txt")
ax.fill(dat[:,0],dat[:,1],color='#ae89c7',alpha=1,lw=0,zorder=-5)
ax.plot(dat[:,0],dat[:,1],color='k',zorder=-5)
    

# ALP before equality
dat = loadtxt("limit_data/AxionPhoton/ALP_CDM.txt")
plt.plot(dat[:,0],dat[:,1]*(137*2*pi),'--',lw=2,zorder=-1,alpha=1,color='k')
plt.arrow(0.202, 0.532, 0.00, -0.02, head_width=0.006, head_length=0.01, linewidth=2, color='k', length_includes_head=False,transform=fig.transFigure,figure=fig)
plt.arrow(0.352, 0.627, 0.00, -0.02, head_width=0.006, head_length=0.01, linewidth=2, color='k', length_includes_head=False,transform=fig.transFigure,figure=fig)
plt.text(1e-13,0.15e-10,r'$m_a(T_{\rm eq}) > 3H(T_{\rm eq})$',fontsize=20,rotation=23,color='k')


# ALP Cogenesis
ax.plot(m,ALP_Cogenesis(m,1)*(137*2*pi),lw=4,color='#52b53c',path_effects=line_background(6,'k'),zorder=-10,solid_capstyle='round')
ax.text(1e-11,0.5e-12,r'{\bf ALP Cogenesis}',color='#52b53c',fontsize=20,rotation=23.5,path_effects=line_background(1,'k'))

# Early matter domination
EMD_lower = 1.448226539542627e-19*2*pi*137
EMD_upper = 2.6761051177154226e-18*2*pi*137
ax.fill_between(m,[EMD_upper,EMD_upper],[EMD_lower,EMD_lower],color='#8596c7',alpha=1,zorder=-100,edgecolor='k',lw=1.5)



m = array([2.5e-12,1e-4])
plt.plot(m,1/(1e12*(5.7e-6/m)),lw=4,color='orange',path_effects=line_background(6,'k'),zorder=-10,solid_capstyle='round')
plt.text(0.2e-10,1e-18,r'\begin{center}{\bf QCD axion \linebreak (pre-inflation)}\end{center}',fontsize=20,rotation=42,color='orange',path_effects=line_background(1,'k'))

m = array([95e-6,450e-6])
plt.plot(m,1/(1e12*(5.7e-6/m)),lw=5,color='crimson',path_effects=line_background(7,'k'),zorder=-10,solid_capstyle='round')

m = array([7e-4,30e-3])
plt.plot(m,1/(1e12*(5.7e-6/m)),lw=5,color='crimson',path_effects=line_background(7,'k'),zorder=-10,solid_capstyle='round')
plt.text(1.3e-4,8e-12,r'\begin{center} {\bf QCD axion \linebreak (post-inflation)}\end{center}',fontsize=20,rotation=42,color='crimson',path_effects=line_background(1,'k'))
plt.text(4.2e-4,0.18e-9,r'$N_{\rm DW}>1$',fontsize=12,color='crimson',alpha=1,rotation=40.5)
plt.text(5.3e-5,0.23e-10,r'$N_{\rm DW}=1$',fontsize=12,color='crimson',alpha=1,rotation=40.5)


ax.text(1e-9,3e-7,r'{\bf If coupled to photons}',color='lightgray',path_effects=line_background(1.5,'k'),fontsize=28)
ax.text(1.5e-4,4e-9,r'{\bf If coupled to nucleons}',color='w',path_effects=line_background(1.5,'k'),fontsize=20)

ax.text(0.7e-12,2.5e-18,r'{\bf Black hole spins}',color='lightgray',rotation=90,fontsize=20,path_effects=line_background(1.5,'k'))

plt.text(0.5e-11,2.5e-16,r'{\bf Trapped misalignment}',color='k',fontsize=20,rotation=40)

plt.text(30e-3,7e-16,r'{\bf ALP misalignment}',fontsize=20,color='k',ha='center',alpha=1)
plt.text(30e-3,7e-16/3.5,r'(early matter domination)',fontsize=20,color='k',ha='center',alpha=1)

ax.annotate("",xy=(2.1e-2,3e-11), xycoords='data',xytext=(3.5e-2,2e-12), textcoords='data',size=15,arrowprops=dict(alpha=1,arrowstyle="simple",facecolor='#6e9971'),zorder=-100)
plt.text(3.7e-2,2.3e-11,r'\noindent Large misalignment/ \newline kinetic fragmentation / \newline frictional misaligment',rotation=12,color='k',fontsize=13)

ax.annotate("",xy=(0.85e-1,1.3e-14), xycoords='data',xytext=(0.5e-1,2e-13), textcoords='data',size=15,arrowprops=dict(alpha=1,arrowstyle="simple",facecolor='#6e9971'),zorder=-100)
plt.text(1.1e-1,6e-14,r'\noindent Tune $\theta_i \to 0$/ \newline frictional misaligment',rotation=12,color='k',fontsize=13)

mvals = array([1e-23,1e3])
fa = 1.2e13*(1e-20/mvals)
plt.text(0.15e-14,0.3e-6,r'\begin{center}{Structure \linebreak formation}\end{center}',rotation=40,fontsize=20,color='w',path_effects=line_background(1,'k'))
plt.fill_between(mvals,1/fa,y2=1,color='dimgray',lw=3,zorder=0.09)
plt.plot(mvals,1/fa,'k-')


# https://arxiv.org/abs/hep-ph/9908508
#Axion_fa.CASPEr(ax,text_pos=[0.4e-8,1.2e-14],text_rot=80,col='#a83279')
#plt.text(0.8e-8,1.2e-14,r'$C_{\rm EDM} = 2.4\times 10^{-16}$ cm',color='#a83279',rotation=80,fontsize=18)
    
    
#plt.text(6e-5,3.3e-12,r'$n = 6$',color=cols[6,:],rotation=40,fontsize=35)
#plt.text(9e-5,0.48e-12,r'$n = 0$',color=cols[0,:],rotation=36,fontsize=35)
#plt.text(4e-6,2e-12,r'{\bf QCD axion}',color='gold',fontsize=35,rotation=70,path_effects=line_background(1.5,'k'))
#plt.text(2e-12,0.3e-13,r'{\bf Black hole spins}',fontsize=35,color='k',rotation=90)


MySaveFig(fig,'Axion_fa_ALPDM')
